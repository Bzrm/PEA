# %%
# !pip install transformers

# %%
# !pip install -U sentence-transformers

# %%
import pandas as pd
import numpy as np

import sklearn

from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# #Данные

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_train = pd.read_csv('train.csv')

# %% [markdown]
# #Векторизация текстов

# %% [markdown]
# В качетве энкодера для текстов взял Bert, дообученный на датасете CoLA. Датасет создан для оценки грамматической приемлемости ("грамматичности") текста, что кажется довольно близкой задачей.

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("textattack/bert-base-uncased-CoLA")

model = AutoModelForSequenceClassification.from_pretrained("textattack/bert-base-uncased-CoLA")

# %%
def get_cola_embedding(text, tokenizer, model):
  input_ids = tokenizer([text], return_tensors="pt").input_ids[:,:512] 
  embedding = model.base_model(input_ids)['pooler_output'][0].numpy()

  return embedding

# %%
with torch.no_grad():
  df_train['text_embedded'] = df_train['discourse_text'].progress_apply(lambda text: get_cola_embedding(text, tokenizer, model))

# %%
train_texts_embeddings = df_train['text_embedded'].tolist()

# %%
df_train[:5]
# Out:
#    Unnamed: 0  discourse_id      essay_id  \
# 0           0  0013cc385424  007ACE74B050
# 1           1  9704a709b505  007ACE74B050
# 2           2  c22adee811b6  007ACE74B050
# 3           3  a10d361e54e4  007ACE74B050
# 4           4  db3e453ec4e2  007ACE74B050
#
#                                       discourse_text discourse_type  \
# 0  Hi, i'm Isaac, i'm going to be writing about h...           Lead
# 1  On my perspective, I think that the face is a ...       Position
# 2  I think that the face is a natural landform be...          Claim
# 3  If life was on Mars, we would know by now. The...       Evidence
# 4  People thought that the face was formed by ali...   Counterclaim
#
#   discourse_effectiveness                                      text_embedded
# 0                Adequate  [-0.17674124 -0.14251244 -0.7324696   0.016722...
# 1                Adequate  [-2.43735537e-01 -7.61663690e-02 -9.62651372e-...
# 2                Adequate  [-7.33554721e-01 -9.37814564e-02 -2.42979348e-...
# 3                Adequate  [ 2.82963723e-01  1.14817008e-01  6.51097298e-...
# 4                Adequate  [-7.25191891e-01 -1.71787202e-01 -5.41366756e-...

# %%
'''
#Векторизуется довольно долго, поэтому сохранял в отдельный csv и потом подгружал с постобработкой
from google.colab import drive
drive.mount('/content/drive')

df_train = pd.read_csv('/content/drive/MyDrive/train_dataset_embedded.csv')

train_texts_embedded = df_train['text_embedded']

train_texts_embeddings = [np.asarray(text.replace('[', '').replace(']', '').replace('\n', '').split(), dtype=float) for text in train_texts_embedded]
'''

# %% [markdown]
# #Векторизация типов

# %% [markdown]
# Вместо того, чтобы напрямую векторизовать тип (через W2V или хотя бы onehot) я взял описания каждого типа со страницы соревнования, векторизовал описание через XLM-Robert'у (обучена на парафразах, поэтому неплохо улавливает семантику) и использовал эти векторы в качестве эмбеддингов типов

# %%
from sentence_transformers import SentenceTransformer, util

# %%
embedder = SentenceTransformer('xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
type_desc_dict = {"Lead" : "an introduction that begins with a statistic, a quotation, a description, or some other device to grab the reader’s attention and point toward the thesis",
"Position" : "an opinion or conclusion on the main question",
"Claim" : "a claim that supports the position",
"Counterclaim" : "a claim that refutes another claim or gives an opposing reason to the position",
"Rebuttal" : "a claim that refutes a counterclaim",
"Evidence" : "ideas or examples that support claims, counterclaims, or rebuttals.",
"Concluding Statement" : "a concluding statement that restates the claims"}

# %%
type_embeddings_dict = {}
for k in type_desc_dict:
  type_embeddings_dict[k] = embedder.encode([type_desc_dict[k]], convert_to_tensor=False)[0]

# %%
df_train['discourse_type_embedding'] = df_train['discourse_type'].progress_apply(lambda discourse_type_label: type_embeddings_dict[discourse_type_label])
# Out:
#   0%|          | 0/36765 [00:00<?, ?it/s]

# %%
discourse_type_embeddings = df_train['discourse_type_embedding'].tolist()

# %% [markdown]
# #Классификация

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
y_train_raw = df_train['discourse_effectiveness'].tolist()

# %%
le.fit(y_train_raw)

y_train_ = le.transform(y_train_raw)

# %% [markdown]
# В качестве X для обучения используем сконкатериванные эмбеддинги текстов и типов

# %%
X_train_ = [np.concatenate((train_texts_embedding, discourse_type_embedding)) for 
           train_texts_embedding, discourse_type_embedding in 
           zip(train_texts_embeddings, discourse_type_embeddings)]

# %%
X_train_[0].shape
# Out:
# (1536,)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_, y_train_, test_size=0.1, random_state=6, shuffle=True)

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd = SGDClassifier(verbose=1, learning_rate='adaptive', penalty='l1', eta0=0.003, early_stopping=True, n_iter_no_change=5)

sgd.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# -- Epoch 1
# Norm: 4.58, NNZs: 1034, Bias: 0.006000, T: 29779, Avg. loss: 0.918160
# Total training time: 0.79 seconds.
# -- Epoch 2
# Norm: 7.55, NNZs: 879, Bias: 0.009000, T: 59558, Avg. loss: 0.853097
# Total training time: 1.92 seconds.
# -- Epoch 3
# Norm: 10.05, NNZs: 758, Bias: 0.006000, T: 89337, Avg. loss: 0.817021
# Total training time: 3.11 seconds.
# -- Epoch 4
# Norm: 12.16, NNZs: 771, Bias: 0.036000, T: 119116, Avg. loss: 0.806781
# Total training time: 3.73 seconds.
# -- Epoch 5
# Norm: 14.03, NNZs: 713, Bias: 0.021000, T: 148895, Avg. loss: 0.795222
# Total training time: 4.33 seconds.
# -- Epoch 6
# Norm: 15.75, NNZs: 677, Bias: 0.024000, T: 178674, Avg. loss: 0.789538
# Total training time: 4.93 seconds.
# -- Epoch 7
# Norm: 17.32, NNZs: 635, Bias: 0.045000, T: 208453, Avg. loss: 0.783974
# Total training time: 5.54 seconds.
# -- Epoch 8
# Norm: 17.39, NNZs: 651, Bias: 0.054000, T: 238232, Avg. loss: 0.693603
# Total training time: 6.14 seconds.
# -- Epoch 9
# Norm: 17.46, NNZs: 643, Bias: 0.054000, T: 268011, Avg. loss: 0.689730
# Total training time: 6.75 seconds.
# -- Epoch 10
# Norm: 17.53, NNZs: 636, Bias: 0.055800, T: 297790, Avg. loss: 0.691182
# Total training time: 7.36 seconds.
# -- Epoch 11
# Norm: 17.61, NNZs: 637, Bias: 0.048600, T: 327569, Avg. loss: 0.689312
# Total training time: 7.97 seconds.
# -- Epoch 12
# Norm: 17.68, NNZs: 632, Bias: 0.048600, T: 357348, Avg. loss: 0.688950
# Total training time: 8.59 seconds.
# -- Epoch 13
# Norm: 17.69, NNZs: 633, Bias: 0.055800, T: 387127, Avg. loss: 0.672994
# Total training time: 9.20 seconds.
# -- Epoch 14
# Norm: 17.69, NNZs: 633, Bias: 0.055440, T: 416906, Avg. loss: 0.672032
# Total training time: 9.82 seconds.
# -- Epoch 15
# Norm: 17.70, NNZs: 633, Bias: 0.056400, T: 446685, Avg. loss: 0.672079
# Total training time: 10.47 seconds.
# -- Epoch 16
# Norm: 17.70, NNZs: 633, Bias: 0.052920, T: 476464, Avg. loss: 0.671956
# Total training time: 11.10 seconds.
# -- Epoch 17
# Norm: 17.71, NNZs: 636, Bias: 0.053640, T: 506243, Avg. loss: 0.671571
# Total training time: 11.71 seconds.
# -- Epoch 18
# Norm: 17.71, NNZs: 633, Bias: 0.054936, T: 536022, Avg. loss: 0.668823
# Total training time: 12.32 seconds.
# -- Epoch 19
# Norm: 17.71, NNZs: 632, Bias: 0.054768, T: 565801, Avg. loss: 0.668472
# Total training time: 12.94 seconds.
# -- Epoch 20
# Norm: 17.71, NNZs: 632, Bias: 0.055032, T: 595580, Avg. loss: 0.668529
# Total training time: 13.55 seconds.
# -- Epoch 21
# Norm: 17.71, NNZs: 633, Bias: 0.055848, T: 625359, Avg. loss: 0.668171
# Total training time: 14.17 seconds.
# -- Epoch 22
# Norm: 17.71, NNZs: 633, Bias: 0.056064, T: 655138, Avg. loss: 0.668422
# Total training time: 14.78 seconds.
# -- Epoch 23
# Norm: 17.71, NNZs: 634, Bias: 0.056237, T: 684917, Avg. loss: 0.667836
# Total training time: 15.41 seconds.
# -- Epoch 24
# Norm: 17.71, NNZs: 634, Bias: 0.056314, T: 714696, Avg. loss: 0.667744
# Total training time: 16.03 seconds.
# -- Epoch 25
# Norm: 17.71, NNZs: 634, Bias: 0.056270, T: 744475, Avg. loss: 0.667761
# Total training time: 16.66 seconds.
# -- Epoch 26
# Norm: 17.71, NNZs: 634, Bias: 0.056328, T: 774254, Avg. loss: 0.667771
# Total training time: 17.27 seconds.
# -- Epoch 27
# Norm: 17.71, NNZs: 634, Bias: 0.056122, T: 804033, Avg. loss: 0.667781
# Total training time: 17.90 seconds.
# -- Epoch 28
# Norm: 17.71, NNZs: 634, Bias: 0.056241, T: 833812, Avg. loss: 0.667578
# Total training time: 18.52 seconds.
# -- Epoch 29
# Norm: 17.71, NNZs: 634, Bias: 0.056265, T: 863591, Avg. loss: 0.667561
# Total training time: 19.14 seconds.
# -- Epoch 30
# Norm: 17.71, NNZs: 634, Bias: 0.056301, T: 893370, Avg. loss: 0.667554
# Total training time: 19.75 seconds.
# -- Epoch 31
# Norm: 17.71, NNZs: 634, Bias: 0.056233, T: 923149, Avg. loss: 0.667532
# Total training time: 20.38 seconds.
# -- Epoch 32
# Norm: 17.71, NNZs: 634, Bias: 0.056264, T: 952928, Avg. loss: 0.667559
# Total training time: 21.00 seconds.
# Convergence after 32 epochs took 21.08 seconds
# -- Epoch 1
# Norm: 3.84, NNZs: 1147, Bias: -0.030000, T: 29779, Avg. loss: 0.537680
# Total training time: 0.49 seconds.
# -- Epoch 2
# Norm: 5.87, NNZs: 911, Bias: -0.018000, T: 59558, Avg. loss: 0.483247
# Total training time: 1.04 seconds.
# -- Epoch 3
# Norm: 7.69, NNZs: 843, Bias: -0.036000, T: 89337, Avg. loss: 0.461459
# Total training time: 1.56 seconds.
# -- Epoch 4
# Norm: 9.26, NNZs: 775, Bias: -0.033000, T: 119116, Avg. loss: 0.449116
# Total training time: 2.08 seconds.
# -- Epoch 5
# Norm: 10.70, NNZs: 745, Bias: -0.042000, T: 148895, Avg. loss: 0.437659
# Total training time: 2.58 seconds.
# -- Epoch 6
# Norm: 11.98, NNZs: 705, Bias: -0.015000, T: 178674, Avg. loss: 0.435755
# Total training time: 3.07 seconds.
# -- Epoch 7
# Norm: 12.01, NNZs: 710, Bias: -0.019200, T: 208453, Avg. loss: 0.377856
# Total training time: 3.55 seconds.
# -- Epoch 8
# Norm: 12.07, NNZs: 695, Bias: -0.025800, T: 238232, Avg. loss: 0.376362
# Total training time: 4.05 seconds.
# -- Epoch 9
# Norm: 12.13, NNZs: 681, Bias: -0.016800, T: 268011, Avg. loss: 0.374965
# Total training time: 4.53 seconds.
# -- Epoch 10
# Norm: 12.19, NNZs: 683, Bias: -0.021600, T: 297790, Avg. loss: 0.373695
# Total training time: 5.02 seconds.
# -- Epoch 11
# Norm: 12.25, NNZs: 680, Bias: -0.022800, T: 327569, Avg. loss: 0.374374
# Total training time: 5.50 seconds.
# -- Epoch 12
# Norm: 12.26, NNZs: 673, Bias: -0.021360, T: 357348, Avg. loss: 0.364155
# Total training time: 5.99 seconds.
# -- Epoch 13
# Norm: 12.26, NNZs: 674, Bias: -0.021360, T: 387127, Avg. loss: 0.363890
# Total training time: 6.47 seconds.
# -- Epoch 14
# Norm: 12.26, NNZs: 673, Bias: -0.019920, T: 416906, Avg. loss: 0.363731
# Total training time: 6.96 seconds.
# -- Epoch 15
# Norm: 12.27, NNZs: 674, Bias: -0.022320, T: 446685, Avg. loss: 0.363495
# Total training time: 7.44 seconds.
# -- Epoch 16
# Norm: 12.27, NNZs: 675, Bias: -0.022320, T: 476464, Avg. loss: 0.363517
# Total training time: 7.93 seconds.
# -- Epoch 17
# Norm: 12.27, NNZs: 675, Bias: -0.021096, T: 506243, Avg. loss: 0.361491
# Total training time: 8.41 seconds.
# -- Epoch 18
# Norm: 12.27, NNZs: 675, Bias: -0.020664, T: 536022, Avg. loss: 0.361387
# Total training time: 8.89 seconds.
# -- Epoch 19
# Norm: 12.27, NNZs: 676, Bias: -0.020232, T: 565801, Avg. loss: 0.361344
# Total training time: 9.38 seconds.
# -- Epoch 20
# Norm: 12.27, NNZs: 675, Bias: -0.020976, T: 595580, Avg. loss: 0.361355
# Total training time: 9.86 seconds.
# -- Epoch 21
# Norm: 12.27, NNZs: 676, Bias: -0.021552, T: 625359, Avg. loss: 0.361311
# Total training time: 10.35 seconds.
# -- Epoch 22
# Norm: 12.27, NNZs: 676, Bias: -0.021163, T: 655138, Avg. loss: 0.360929
# Total training time: 10.84 seconds.
# -- Epoch 23
# Norm: 12.28, NNZs: 676, Bias: -0.021077, T: 684917, Avg. loss: 0.360865
# Total training time: 11.33 seconds.
# -- Epoch 24
# Norm: 12.28, NNZs: 676, Bias: -0.020923, T: 714696, Avg. loss: 0.360881
# Total training time: 11.82 seconds.
# -- Epoch 25
# Norm: 12.28, NNZs: 676, Bias: -0.021192, T: 744475, Avg. loss: 0.360916
# Total training time: 12.30 seconds.
# -- Epoch 26
# Norm: 12.28, NNZs: 676, Bias: -0.021149, T: 774254, Avg. loss: 0.360897
# Total training time: 12.78 seconds.
# -- Epoch 27
# Norm: 12.28, NNZs: 676, Bias: -0.021138, T: 804033, Avg. loss: 0.360776
# Total training time: 13.28 seconds.
# -- Epoch 28
# Norm: 12.28, NNZs: 676, Bias: -0.021096, T: 833812, Avg. loss: 0.360777
# Total training time: 13.76 seconds.
# -- Epoch 29
# Norm: 12.28, NNZs: 676, Bias: -0.021124, T: 863591, Avg. loss: 0.360768
# Total training time: 14.25 seconds.
# -- Epoch 30
# Norm: 12.28, NNZs: 676, Bias: -0.021109, T: 893370, Avg. loss: 0.360769
# Total training time: 14.74 seconds.
# -- Epoch 31
# Norm: 12.28, NNZs: 675, Bias: -0.021110, T: 923149, Avg. loss: 0.360770
# Total training time: 15.23 seconds.
# Convergence after 31 epochs took 15.30 seconds
# -- Epoch 1
# Norm: 3.12, NNZs: 1005, Bias: -0.018000, T: 29779, Avg. loss: 0.469534
# Total training time: 0.48 seconds.
# -- Epoch 2
# Norm: 5.17, NNZs: 859, Bias: -0.039000, T: 59558, Avg. loss: 0.438479
# Total training time: 1.02 seconds.
# -- Epoch 3
# Norm: 6.81, NNZs: 770, Bias: -0.051000, T: 89337, Avg. loss: 0.424088
# Total training time: 1.55 seconds.
# -- Epoch 4
# Norm: 8.22, NNZs: 722, Bias: -0.045000, T: 119116, Avg. loss: 0.417571
# Total training time: 2.06 seconds.
# -- Epoch 5
# Norm: 9.48, NNZs: 675, Bias: -0.066000, T: 148895, Avg. loss: 0.414600
# Total training time: 2.55 seconds.
# -- Epoch 6
# Norm: 10.65, NNZs: 664, Bias: -0.081000, T: 178674, Avg. loss: 0.407440
# Total training time: 3.18 seconds.
# -- Epoch 7
# Norm: 11.74, NNZs: 645, Bias: -0.087000, T: 208453, Avg. loss: 0.405111
# Total training time: 3.83 seconds.
# -- Epoch 8
# Norm: 12.74, NNZs: 610, Bias: -0.096000, T: 238232, Avg. loss: 0.401959
# Total training time: 4.44 seconds.
# -- Epoch 9
# Norm: 13.70, NNZs: 589, Bias: -0.111000, T: 268011, Avg. loss: 0.399792
# Total training time: 5.11 seconds.
# -- Epoch 10
# Norm: 13.72, NNZs: 576, Bias: -0.115800, T: 297790, Avg. loss: 0.347804
# Total training time: 5.76 seconds.
# -- Epoch 11
# Norm: 13.74, NNZs: 549, Bias: -0.111600, T: 327569, Avg. loss: 0.343199
# Total training time: 6.41 seconds.
# -- Epoch 12
# Norm: 13.77, NNZs: 552, Bias: -0.115800, T: 357348, Avg. loss: 0.341445
# Total training time: 7.06 seconds.
# -- Epoch 13
# Norm: 13.80, NNZs: 544, Bias: -0.118200, T: 387127, Avg. loss: 0.340172
# Total training time: 7.52 seconds.
# -- Epoch 14
# Norm: 13.83, NNZs: 538, Bias: -0.120000, T: 416906, Avg. loss: 0.338755
# Total training time: 7.99 seconds.
# -- Epoch 15
# Norm: 13.83, NNZs: 531, Bias: -0.119520, T: 446685, Avg. loss: 0.330310
# Total training time: 8.45 seconds.
# -- Epoch 16
# Norm: 13.82, NNZs: 530, Bias: -0.120600, T: 476464, Avg. loss: 0.329552
# Total training time: 8.91 seconds.
# -- Epoch 17
# Norm: 13.82, NNZs: 528, Bias: -0.120720, T: 506243, Avg. loss: 0.329445
# Total training time: 9.37 seconds.
# -- Epoch 18
# Norm: 13.82, NNZs: 528, Bias: -0.120600, T: 536022, Avg. loss: 0.329163
# Total training time: 9.82 seconds.
# -- Epoch 19
# Norm: 13.82, NNZs: 532, Bias: -0.121560, T: 565801, Avg. loss: 0.328846
# Total training time: 10.28 seconds.
# -- Epoch 20
# Norm: 13.82, NNZs: 530, Bias: -0.121344, T: 595580, Avg. loss: 0.327150
# Total training time: 10.74 seconds.
# -- Epoch 21
# Norm: 13.82, NNZs: 530, Bias: -0.121200, T: 625359, Avg. loss: 0.327124
# Total training time: 11.20 seconds.
# -- Epoch 22
# Norm: 13.82, NNZs: 530, Bias: -0.121272, T: 655138, Avg. loss: 0.327051
# Total training time: 11.65 seconds.
# -- Epoch 23
# Norm: 13.82, NNZs: 530, Bias: -0.121464, T: 684917, Avg. loss: 0.327038
# Total training time: 12.11 seconds.
# -- Epoch 24
# Norm: 13.82, NNZs: 527, Bias: -0.121416, T: 714696, Avg. loss: 0.326906
# Total training time: 12.57 seconds.
# -- Epoch 25
# Norm: 13.82, NNZs: 527, Bias: -0.121478, T: 744475, Avg. loss: 0.326602
# Total training time: 13.03 seconds.
# -- Epoch 26
# Norm: 13.82, NNZs: 527, Bias: -0.121330, T: 774254, Avg. loss: 0.326567
# Total training time: 13.49 seconds.
# -- Epoch 27
# Norm: 13.82, NNZs: 527, Bias: -0.121512, T: 804033, Avg. loss: 0.326542
# Total training time: 13.95 seconds.
# -- Epoch 28
# Norm: 13.82, NNZs: 527, Bias: -0.121531, T: 833812, Avg. loss: 0.326538
# Total training time: 14.41 seconds.
# -- Epoch 29
# Norm: 13.82, NNZs: 527, Bias: -0.121584, T: 863591, Avg. loss: 0.326488
# Total training time: 14.86 seconds.
# -- Epoch 30
# Norm: 13.82, NNZs: 528, Bias: -0.121484, T: 893370, Avg. loss: 0.326441
# Total training time: 15.32 seconds.
# -- Epoch 31
# Norm: 13.82, NNZs: 528, Bias: -0.121531, T: 923149, Avg. loss: 0.326463
# Total training time: 15.78 seconds.
# -- Epoch 32
# Norm: 13.82, NNZs: 528, Bias: -0.121521, T: 952928, Avg. loss: 0.326449
# Total training time: 16.25 seconds.
# -- Epoch 33
# Norm: 13.82, NNZs: 528, Bias: -0.121583, T: 982707, Avg. loss: 0.326449
# Total training time: 16.71 seconds.
# -- Epoch 34
# Norm: 13.82, NNZs: 528, Bias: -0.121564, T: 1012486, Avg. loss: 0.326445
# Total training time: 17.17 seconds.
# Convergence after 34 epochs took 17.25 seconds
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   54.0s finished
# SGDClassifier(early_stopping=True, eta0=0.003, learning_rate='adaptive',
#               penalty='l1', verbose=1)

# %%
sgd.score(X_val, y_val)
# Out:
# 0.6565134620614631
